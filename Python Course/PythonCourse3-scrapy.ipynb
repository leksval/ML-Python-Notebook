# %% [markdown]
# # Utworzenie scrapera wydobywającego dane o opiniach na temat hotelów w wybranym mieście. Dane pochodzą z booking.com

# %%
from scrapy import Spider
from scrapy.crawler import CrawlerProcess

# %%
import logging
import os

# %% [markdown]
# !dir   --> dodanie wykrzyknika powoduje wykonanie polecenia powłoki

# %% [markdown]
# ##### Funkcja próbująca usunąć plik jeśli już istnieje w celu uniknięcia błędów i dopisywania danych

# %%
def try_remove (filename):
    try:
        os.remove(filename)
    except OSError:
        pass

# %% [markdown]
# #### Właściwa klasa scrapująca:

# %%
class BookingComOPinions(Spider):
    name = 'BookingComOpinionsSpider' # nazwa jest obowiązkowa
    
    custom_settings = {
        'FEED_URI': '%(json_file)s', # zapisanie rezultatów do pliku %()s wrzua do pola argument który jest stringiem s, wykrywa jedyny string pobrany jako argument
        'FEED_FORMAT': 'json',       # wybór sposobu formatowania rezultatów
        'DOWNLOAD_DELAY': 3,         # trzeba uważać żeby nie dać za małego czasu bo można zostać zbanowanym
        'LOG_LEVEL': logging.DEBUG,  # poziom wartości informacji jakie będą wyświetlane (debug, warn error itp)
        'EXTENSIONS': {
            'scrapy.extensions.closespider.CloseSpider':1 # klasa która pozwala wykorzystać specjalny rodzaj wyjątku który powinien zatrzymać pająka
                                                          # CloseSpider przydaje się np. gdy dostaliśmy bana od strony więc nie ma sensu dalej szuka
        },
        'CLOSESPIDER_ITEMCOUNT': 10 # system zatrzyma się po porównaniu 10 hoteli
    }
    
    def parse (self, response):               # funkcja która będzie analizowała już wybraną stronę
        hotels = response.css('div.sr_item')  # lista bloków w których są opisane hotele
        for hotel in hotels:
            hotel_name = hotel.css('span.sr-hotel__name::text').get().strip() # hotel jest selektorem samym w sobie więc można na nim wykonać metodę .css() 
                                                                              # strip() obcinanie białych znaków z tekstu
            hotel_link = hotel.css('.hotel_name_link.url').pop()
            yield response.follow(hotel_link, self.parse_hotel,
                                 meta={'hotel': hotel_name})     # zakładamy historię meta-informacji która będzie działać w głąb
        
 #       for link in response.css('a[data-page-next]'): #pop() nie moze tu byc bo na ostatniej stronie brak elementu
 #           #zamiast tego petla ktora jest instrukcja warunkowa jesli element jest to wykonaj, a jak nie to nie wykonaj
 #           yield response.follow(link)
            
    def parse_hotel (self, response):
        hotel_name = response.meta['hotel']                         # wykorzystanie wcześniej utworzonych meta danych do wydobycia nazwy
        for reviews_link in response.css('a.show_all_reviews_btn'): # parsowanie ścieżki do opinii o hotelu
            yield response.follow(reviews_link, self.parse_reviews, # przekazanie nazwy funkcji bez wywołania
                                 meta={'hotel': hotel_name})        # forwardowanie metadanych (same się nie dziedziczą)
        
    def parse_reviews (self, response):
        hotel_name = response.meta['hotel']   
        items = response.css('li.review_item')
        for item in items:
            publish_date = item.css('meta[itemprop="datePublished"]'
                                   '::attr(content)').get('')        # funkcja get nie wydobędzie niczego (zwraca None) chyba że w nawiasach od get wstawi się wartość domyślnątu '',  gdy nie ma szukanego selektora
            reviewer = item.css('div.review_item_reviewer')
            rev_count = reviewer.css('div.'
                                    'review_item_user_review_count::text').get('')
            ...
            
            review = item.css('div.review_item_review')
            rating = item.css('meta[itemprop="ratingValue"]'
                                   '::attr(content)').get('')
            raw_tags = review.css('li.review_info_tag::text').getall()
            tags= list(filter(None, map(str.strip, raw_tags)))
            ...
                  # pierwszym parametrem filter może być None (wyłapuje puste stringi), a drugi to lista ?? lub tekst?? filtrowana/y
            yield{
                'hotel': hotel_name,
                'publish_date': publish_date,
                'rev_count': rev_count,
                'rating': rating,
                'tags': tags
            }
        
        for next_page in response.css('a#review_next_page_link'): # '#' bo szukamy po id  
            yield response.follow(next_page, self.parse_reviews,
                                 meta=response.meta)

# %%
ENTRY_URL = 'https://www.booking.com/searchresults.pl.html?city=-273837'

# %%
json_file = 'Oslo.json' # przypisanie nowej nazwy do pliku
try_remove(json_file)   # usuwanie pliku jeśli istnieje

# %% [markdown]
# ##### Przygotowanie procesu przez crawlera, spider jest przygotowany i gotowy do pracy:

# %%
process = CrawlerProcess()
process.crawl(BookingComOPinions, start_urls = [ENTRY_URL],
             json_file = json_file)
# start_urls to lista tych adresów z których rozpoczynam przeszukiwanie
# Out:
# 2019-04-11 14:22:07 [scrapy.utils.log] INFO: Scrapy 1.5.2 started (bot: scrapybot)
# 2019-04-11 14:22:07 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 18.9.0, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1a  20 Nov 2018), cryptography 2.4.2, Platform Windows-10-10.0.17134-SP0
# 2019-04-11 14:22:07 [scrapy.crawler] INFO: Overridden settings: {'CLOSESPIDER_ITEMCOUNT': 10, 'DOWNLOAD_DELAY': 3, 'FEED_FORMAT': 'json', 'FEED_URI': '%(json_file)s', 'LOG_LEVEL': 10}
# 2019-04-11 14:22:07 [scrapy.extensions.telnet] INFO: Telnet Password: 7cbf95f83d42775b
# 2019-04-11 14:22:07 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.closespider.CloseSpider']
# 2019-04-11 14:22:07 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-04-11 14:22:07 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-04-11 14:22:07 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-04-11 14:22:07 [scrapy.core.engine] INFO: Spider opened
# 2019-04-11 14:22:07 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-11 14:22:07 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023

# %% [markdown]
# #### Uruchomienie procesu scrapowania:

# %%
process.start()
# Out:
# 2019-04-11 14:22:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?city=-273837> (referer: None)
# 2019-04-11 14:22:12 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/citybox-oslo.pl.html> from <GET https://www.booking.com/hotel/no/citybox-oslo.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:15 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/radisson-blu-oslo-alna.pl.html> from <GET https://www.booking.com/hotel/no/radisson-blu-oslo-alna.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:19 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/opera-apartments.pl.html> from <GET https://www.booking.com/hotel/no/opera-apartments.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:23 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/forenom-aparthotel-oslo-city.pl.html> from <GET https://www.booking.com/hotel/no/forenom-aparthotel-oslo-city.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:26 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/maya-apartments-thorvald-meyers-gt-38.pl.html> from <GET https://www.booking.com/hotel/no/maya-apartments-thorvald-meyers-gt-38.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:31 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/radisson-blu-nydalen.pl.html> from <GET https://www.booking.com/hotel/no/radisson-blu-nydalen.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:35 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/first-millennium.pl.html> from <GET https://www.booking.com/hotel/no/first-millennium.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:38 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/first-noble-house.pl.html> from <GET https://www.booking.com/hotel/no/first-noble-house.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:42 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/frogner-house-apartments-arbins-gate-3.pl.html> from <GET https://www.booking.com/hotel/no/frogner-house-apartments-arbins-gate-3.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:46 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/oslo-apartments-dronningensgate-15.pl.html> from <GET https://www.booking.com/hotel/no/oslo-apartments-dronningensgate-15.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:50 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/norlandia-karl-johan-hotell.pl.html> from <GET https://www.booking.com/hotel/no/norlandia-karl-johan-hotell.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:53 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/radisson-blu-plaza-oslo.pl.html> from <GET https://www.booking.com/hotel/no/radisson-blu-plaza-oslo.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:22:58 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/anker-hotel.pl.html> from <GET https://www.booking.com/hotel/no/anker-hotel.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:23:02 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/clarion-royal-christiania.pl.html> from <GET https://www.booking.com/hotel/no/clarion-royal-christiania.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:23:04 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/no/smarthotel-oslo.pl.html> from <GET https://www.booking.com/hotel/no/smarthotel-oslo.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-11 14:23:07 [scrapy.extensions.logstats] INFO: Crawled 1 pages (at 1 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-11 14:23:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/citybox-oslo.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/radisson-blu-oslo-alna.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/opera-apartments.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/forenom-aparthotel-oslo-city.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/maya-apartments-thorvald-meyers-gt-38.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/radisson-blu-nydalen.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/first-millennium.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/first-noble-house.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:36 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.booking.com/hotel/no/first-noble-house.pl.html#blockdisplay4> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2019-04-11 14:23:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/frogner-house-apartments-arbins-gate-3.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/oslo-apartments-dronningensgate-15.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/norlandia-karl-johan-hotell.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/radisson-blu-plaza-oslo.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/anker-hotel.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:23:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/clarion-royal-christiania.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:24:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/no/smarthotel-oslo.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-273837)
# 2019-04-11 14:24:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html> (referer: https://www.booking.com/hotel/no/citybox-oslo.pl.html)
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2019-03-22', 'rev_count': '\n2 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2019-01-09', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-12-08', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '4 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-10-22', 'rev_count': '\n12 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-10-05', 'rev_count': '\n26 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-24', 'rev_count': '\n17 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój rodzinny', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-10', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-04', 'rev_count': '\n12 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-08-03', 'rev_count': '\n4 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-05-06', 'rev_count': '\n40 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.engine] INFO: Closing spider (closespider_itemcount)
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-03-30', 'rev_count': '\n59 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-03-14', 'rev_count': '\n14 opinii\n', 'rating': '8.3', 'tags': ['Grupa', 'Pokój rodzinny', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-01-26', 'rev_count': '\n10 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '5 noclegów']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-01-02', 'rev_count': '\n11 opinii\n', 'rating': '7.5', 'tags': ['Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-11-03', 'rev_count': '\n13 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-08-23', 'rev_count': '\n16 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-07-21', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-07-02', 'rev_count': '\n49 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-06-28', 'rev_count': '\n4 opinie\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-05-12', 'rev_count': '\n38 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-05-07', 'rev_count': '\n80 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2019-03-06', 'rev_count': '\n19 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2019-02-25', 'rev_count': '\n31 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2019-02-17', 'rev_count': '\n15 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Mały pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-11-26', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-11-25', 'rev_count': '\n1 opinia\n', 'rating': '8.5', 'tags': ['Grupa', 'Mały pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-10-28', 'rev_count': '\n17 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-12', 'rev_count': '\n4 opinie\n', 'rating': '8', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Mały pokój Dwuosobowy', '4 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-10', 'rev_count': '\n8 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa', '2 pokoje', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-09-06', 'rev_count': '\n15 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd służbowy', 'Podróżujący ze znajomymi', 'Pokój z 2 łóżkami pojedynczymi', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-06-27', 'rev_count': '\n10 opinii\n', 'rating': '9.2', 'tags': ['Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-06-20', 'rev_count': '\n40 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-02-14', 'rev_count': '\n2 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Mały pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-01-20', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój rodzinny', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2018-01-02', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-12-16', 'rev_count': '\n2 opinie\n', 'rating': '7.5', 'tags': ['Podróżujący w pojedynkę', 'Mały pokój jednoosobowy', '1 nocleg']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-11-11', 'rev_count': '\n84 opinie\n', 'rating': '5', 'tags': ['Podróżujący w pojedynkę', 'Pokój jednoosobowy', '3 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-10-22', 'rev_count': '\n6 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-09-29', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Mały pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-09-18', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Podróżujący ze znajomymi', 'Mały pokój Dwuosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-07-04', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Podróżujący w pojedynkę', 'Mały pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-06-04', 'rev_count': '\n6 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2017-05-26', 'rev_count': '\n1 opinia\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój rodzinny', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-05-05', 'rev_count': '\n10 opinii\n', 'rating': '4.2', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-04-21', 'rev_count': '\n22 opinie\n', 'rating': '5.8', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-04-16', 'rev_count': '\n28 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-04-05', 'rev_count': '\n5 opinii\n', 'rating': '8.3', 'tags': ['W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-03-02', 'rev_count': '\n14 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-01-23', 'rev_count': '\n12 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-11-09', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-10-16', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-10-15', 'rev_count': '\n34 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-09-03', 'rev_count': '\n2 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-08-26', 'rev_count': '\n7 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-08-06', 'rev_count': '\n4 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-07-05', 'rev_count': '\n14 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-04-30', 'rev_count': '\n5 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-04-20', 'rev_count': '\n9 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-03-25', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-04-21', 'rev_count': '\n12 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-04-12', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-02-09', 'rev_count': '\n27 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2016-02-09', 'rev_count': '\n17 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-11-17', 'rev_count': '\n25 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-11-03', 'rev_count': '\n43 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-11-02', 'rev_count': '\n12 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-10-20', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-10-18', 'rev_count': '\n12 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-10-03', 'rev_count': '\n83 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-09-04', 'rev_count': '\n211 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-07-28', 'rev_count': '\n60 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-06-09', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-04-21', 'rev_count': '\n4 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-03-14', 'rev_count': '\n2 opinie\n', 'rating': '9.2', 'tags': ['W parze']}
# 2019-04-11 14:24:05 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/citybox-oslo.pl.html>
# {'hotel': 'Citybox Oslo', 'publish_date': '2015-02-17', 'rev_count': '\n35 opinii\n', 'rating': '8', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:07 [scrapy.extensions.logstats] INFO: Crawled 17 pages (at 16 pages/min), scraped 75 items (at 75 items/min)
# 2019-04-11 14:24:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html> (referer: https://www.booking.com/hotel/no/radisson-blu-oslo-alna.pl.html)
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2019-03-26', 'rev_count': '\n4 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój typu Standard', '5 noclegów']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-12-01', 'rev_count': '\n3 opinie\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój typu Standard', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-11-18', 'rev_count': '\n21 opinii\n', 'rating': '9.6', 'tags': ['W parze', 'Pokój typu Standard', '3 noclegi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-10-16', 'rev_count': '\n62 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Standard', '1 nocleg']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-09-20', 'rev_count': '\n3 opinie\n', 'rating': '2.5', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój typu Standard', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-08-19', 'rev_count': '\n5 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój typu Standard', '1 nocleg']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-07-26', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój typu Standard', '6 noclegów']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-04-30', 'rev_count': '\n2 opinie\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Standard', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2017-11-09', 'rev_count': '\n3 opinie\n', 'rating': '4.6', 'tags': ['Rodzina z małymi dziećmi', 'Pokój typu Standard', '1 nocleg']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2019-03-12', 'rev_count': '\n2 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój typu Standard', '3 noclegi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2019-03-10', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Grupa', 'Pokój typu Standard', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-10-18', 'rev_count': '\n5 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Standard', '1 nocleg']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-09-24', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Podróżujący w pojedynkę', 'Pokój typu Standard', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-09-17', 'rev_count': '\n4 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój typu Standard', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-08-30', 'rev_count': '\n21 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Standard', '4 noclegi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-08-16', 'rev_count': '\n20 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój typu Standard', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-08-16', 'rev_count': '\n56 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój typu Premium', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-05-02', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Standard', '4 noclegi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-05-01', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Rodzina z małymi dziećmi', 'Pokój rodzinny', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-04-02', 'rev_count': '\n27 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój typu Standard', '2 noclegi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-03-26', 'rev_count': '\n16 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój typu Standard', '1 nocleg']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-03-26', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój rodzinny', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2018-03-12', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój rodzinny', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2017-07-16', 'rev_count': '\n10 opinii\n', 'rating': '9.2', 'tags': ['W parze', 'Pokój typu Standard', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2016-03-22', 'rev_count': '\n21 opinii\n', 'rating': '9.2', 'tags': ['W parze']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2016-05-17', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2015-11-01', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['W parze']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2015-05-17', 'rev_count': '\n11 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2015-05-05', 'rev_count': '\n1 opinia\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:09 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/radisson-blu-oslo-alna.pl.html>
# {'hotel': 'Radisson Blu Hotel Oslo Alna', 'publish_date': '2015-05-03', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html> (referer: https://www.booking.com/hotel/no/opera-apartments.pl.html)
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2018-06-04', 'rev_count': '\n19 opinii\n', 'rating': '6.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament (3 osoby dorosłe) - Sørenga', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2018-05-09', 'rev_count': '\n21 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 2 sypialniami i widokiem na miasto', '5 noclegów']}
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2017-07-25', 'rev_count': '\n12 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament z 1 sypialnią', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2018-09-03', 'rev_count': '\n6 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament z 1 sypialnią – Sørenga', '8 noclegów']}
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2017-05-19', 'rev_count': '\n2 opinie\n', 'rating': '2.5', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Apartament z 2 sypialniami', '13 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/opera-apartments.pl.html>
# {'hotel': 'BJØRVIKA APARTMENTS, Opera Area, Oslo city center', 'publish_date': '2015-01-14', 'rev_count': '\n11 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Grupa']}
# 2019-04-11 14:24:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html> (referer: https://www.booking.com/hotel/no/forenom-aparthotel-oslo-city.pl.html)
# 2019-04-11 14:24:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html>
# {'hotel': 'Forenom Aparthotel Oslo', 'publish_date': '2019-02-17', 'rev_count': '\n2 opinie\n', 'rating': '4.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament typu studio dla 2 osób', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html>
# {'hotel': 'Forenom Aparthotel Oslo', 'publish_date': '2018-09-23', 'rev_count': '\n18 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Apartament typu studio dla 2 osób', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html>
# {'hotel': 'Forenom Aparthotel Oslo', 'publish_date': '2018-08-28', 'rev_count': '\n48 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z 2 sypialniami dla 4 osób', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html>
# {'hotel': 'Forenom Aparthotel Oslo', 'publish_date': '2019-02-20', 'rev_count': '\n7 opinii\n', 'rating': '10', 'tags': ['Podróżujący w pojedynkę', 'Ministudio z balkonem (2 osoby)', '1 nocleg']}
# 2019-04-11 14:24:16 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/forenom-aparthotel-oslo-city.pl.html>
# {'hotel': 'Forenom Aparthotel Oslo', 'publish_date': '2018-11-18', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Ministudio z balkonem (2 osoby)', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/no/hotel/maya-apartments-thorvald-meyers-gt-38.pl.html> (referer: https://www.booking.com/hotel/no/maya-apartments-thorvald-meyers-gt-38.pl.html)
# 2019-04-11 14:24:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/maya-apartments-thorvald-meyers-gt-38.pl.html>
# {'hotel': 'Maya Apartments - Thorvald Meyers gt. 38', 'publish_date': '2018-11-20', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Apartament typu Superior', '3 noclegi']}
# 2019-04-11 14:24:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/maya-apartments-thorvald-meyers-gt-38.pl.html>
# {'hotel': 'Maya Apartments - Thorvald Meyers gt. 38', 'publish_date': '2018-09-24', 'rev_count': '\n5 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament typu Standard', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/maya-apartments-thorvald-meyers-gt-38.pl.html>
# {'hotel': 'Maya Apartments - Thorvald Meyers gt. 38', 'publish_date': '2018-07-03', 'rev_count': '\n5 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Apartament z tarasem', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/maya-apartments-thorvald-meyers-gt-38.pl.html>
# {'hotel': 'Maya Apartments - Thorvald Meyers gt. 38', 'publish_date': '2019-03-05', 'rev_count': '\n6 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Apartament typu studio', '3 noclegi']}
# ...
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-01-27', 'rev_count': '\n1 opinia\n', 'rating': '6.7', 'tags': ['Podróżujący w pojedynkę', 'Mały pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-11-29', 'rev_count': '\n7 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '3 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-11-23', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Mały pokój Dwuosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-11-06', 'rev_count': '\n40 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Mały pokój Dwuosobowy', '1 nocleg']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-07-25', 'rev_count': '\n21 opinii\n', 'rating': '2.9', 'tags': ['W parze', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-05-31', 'rev_count': '\n70 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2019-03-14', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Mały pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2019-02-12', 'rev_count': '\n5 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2019-01-30', 'rev_count': '\n25 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2019-01-14', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-10-08', 'rev_count': '\n5 opinii\n', 'rating': '9.2', 'tags': ['Podróżujący ze znajomymi', 'Pokój Dwuosobowy typu Superior', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-07-17', 'rev_count': '\n12 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Mały pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-06-23', 'rev_count': '\n6 opinii\n', 'rating': '8.3', 'tags': ['Ze zwierzęciem', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-06-05', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-04-30', 'rev_count': '\n8 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-04-21', 'rev_count': '\n6 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd służbowy', 'W parze', 'Mały pokój Dwuosobowy', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-04-15', 'rev_count': '\n23 opinie\n', 'rating': '8.3', 'tags': ['Podróżujący w pojedynkę', 'Mały pokój jednoosobowy', '4 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-02-12', 'rev_count': '\n2 opinie\n', 'rating': '4.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2018-01-28', 'rev_count': '\n8 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój rodzinny', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-12-07', 'rev_count': '\n4 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', '2 pokoje', '1 nocleg']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-11-16', 'rev_count': '\n1 opinia\n', 'rating': '3.3', 'tags': ['Wyjazd służbowy', 'Grupa', 'Mały pokój Dwuosobowy', '3 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-10-02', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Grupa', 'Mały pokój jednoosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-09-17', 'rev_count': '\n46 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Grupa', 'Mały pokój Dwuosobowy', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-08-05', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '4 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-08-02', 'rev_count': '\n3 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Mały pokój Dwuosobowy', '6 noclegów']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-07-15', 'rev_count': '\n36 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-07-04', 'rev_count': '\n6 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', '2 pokoje', '1 nocleg']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-06-19', 'rev_count': '\n5 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój rodzinny', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2017-06-02', 'rev_count': '\n1 opinia\n', 'rating': '6.7', 'tags': ['Wyjazd służbowy', 'Grupa', 'Mały pokój Dwuosobowy', '2 noclegi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2016-05-26', 'rev_count': '\n5 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2016-03-23', 'rev_count': '\n7 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-08-24', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-06-18', 'rev_count': '\n7 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-06-07', 'rev_count': '\n12 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2016-05-22', 'rev_count': '\n2 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-10-27', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-09-19', 'rev_count': '\n1 opinia\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-08-15', 'rev_count': '\n2 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-07-31', 'rev_count': '\n62 opinie\n', 'rating': '5', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-07-28', 'rev_count': '\n25 opinii\n', 'rating': '9.2', 'tags': ['Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-07-26', 'rev_count': '\n10 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-07-03', 'rev_count': '\n3 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina ze starszymi dziećmi']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-06-30', 'rev_count': '\n16 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-06-21', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-05-19', 'rev_count': '\n10 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-04-30', 'rev_count': '\n8 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze']}
# 2019-04-11 14:24:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/no/hotel/smarthotel-oslo.pl.html>
# {'hotel': 'Smarthotel Oslo', 'publish_date': '2015-02-08', 'rev_count': '\n7 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę']}
# 2019-04-11 14:24:47 [scrapy.extensions.feedexport] INFO: Stored json feed (314 items) in: Oslo.json
# 2019-04-11 14:24:47 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 23692,
#  'downloader/request_count': 43,
#  'downloader/request_method_count/GET': 43,
#  'downloader/response_bytes': 4088118,
#  'downloader/response_count': 43,
#  'downloader/response_status_count/200': 28,
#  'downloader/response_status_count/301': 15,
#  'dupefilter/filtered': 3,
#  'finish_reason': 'closespider_itemcount',
#  'finish_time': datetime.datetime(2019, 4, 11, 12, 24, 47, 929890),
#  'item_scraped_count': 314,
#  'log_count/DEBUG': 359,
#  'log_count/INFO': 11,
#  'request_depth_max': 3,
#  'response_received_count': 28,
#  'scheduler/dequeued': 43,
#  'scheduler/dequeued/memory': 43,
#  'scheduler/enqueued': 45,
#  'scheduler/enqueued/memory': 45,
#  'start_time': datetime.datetime(2019, 4, 11, 12, 22, 7, 891977)}
# 2019-04-11 14:24:47 [scrapy.core.engine] INFO: Spider closed (closespider_itemcount)

# %% [markdown]
# ##### get() , getall() redukuje selektory od stringu

# %% [markdown]
# ##### .pop(0)  zdejmuje pierwszy element z listy

# %% [markdown]
# # Po wyscrapowaniu danych ze strony można przystąpić do przygotowania ich do analizy:

# %%
logging.getLogger().setLevel(logging.INFO) 
# zmiana levelu wyświetlania info

# %%
import pandas as pd

# %%
df = pd.read_json(json_file) 
# df bo dataframe

# %% [markdown]
# ##### wyrzuamy napisy zawierające litery opiniae i spacje

# %%
df['rev_count'] = (df['rev_count'].str.strip()).str.strip(' opinea')
# df['rev_count'].str.strip() nie modyfikuje to dataframe, chyba że przypiszemy do tego samego obiektu

# %% [markdown]
# ##### Konwersja do intów:

# %%
df['rev_count'] = df['rev_count'].astype(int)

# %%
df['rev_count']
# Out:
# 0       2
# 1       3
# 2       4
# 3      12
# 4      26
# 5      17
# 6       1
# 7      12
# 8       4
# 9      40
# 10     59
# 11     14
# 12     10
# 13     11
# 14     13
# 15     16
# 16      3
# 17     49
# 18      4
# 19     38
# 20     80
# 21     19
# 22     31
# 23     15
# 24      2
# 25      1
# 26     17
# 27      4
# 28      8
# 29     15
#        ..
# 284     2
# 285     8
# 286     4
# 287     1
# 288     3
# 289    46
# 290     1
# 291     3
# 292    36
# 293     6
# 294     5
# 295     1
# 296     5
# 297     7
# 298     4
# 299     7
# 300    12
# 301     2
# 302     1
# 303     1
# 304     2
# 305    62
# 306    25
# 307    10
# 308     3
# 309    16
# 310     3
# 311    10
# 312     8
# 313     7
# Name: rev_count, Length: 314, dtype: int32

# %% [markdown]
# ##### Prygotowanie danych do sprawdzenia jakie tagi wpływają na rating:

# %%
subset = df[['rating', 'tags']] 
subdf = [subset]

# %%
dum = subdf['tags'].map(lambda tags: '|'.join(tags)).str.get_dummies() 
# łączymy tagi dla danej opinii i dzielimy je separatorem  (w get_dummies() domyślny separator to |)

# %%
indicators = pd.concat([subdf['rating'], dum], axis = 1) 
# axis mówi wzdłóż której osi ma nastąpić złączenie

# %%
melted = pd.melt(indicators, id_vars=['rating'])
# id_vars zmienne które zostawiamy w spokoju

# %% [markdown]
# ##### Selekcjonowanie według kryterium:

# %%
positive = melted['value'] == 1
# wydobywamy wyrażenia z samymi 1 (a raczej odpowiedź na pytanie czy występuje w danym indeksie)
# taka lista może posłużyćza selektor danych w dataframe

# %%
selected = melted[positive]

# %%
aggregated = selected.groupby(['variable'])['rating'].agg(['mean','count'])
# groupby() wymaga podania listy tych kolumn wedłóg których ma nastąpić grupowanie
# fragment z rating to wycięcie interesującej kolumny
# agg() metoda agregacji przyjmująca jako parametr sposób agregowania, np. funkcja/słownik

# %% [markdown]
# ##### na koniec będzie sortowanie w celu zwizualizowanie jaki tag wpływa najbardziej na rating:

# %%
aggregated.sort_values(by = ['count']).tali(10) 
# sortowanie rosnąco według wartości count (10 ostatnich pozycji)

# %% [markdown]
# # KONIEC
