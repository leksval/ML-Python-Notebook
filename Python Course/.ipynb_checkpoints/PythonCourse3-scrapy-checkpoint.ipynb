# %% [markdown]
# # Utworzenie scrapera wydobywającego dane o opiniach na temat hotelów w wybranym mieście. Dane pochodzą z booking.com

# %%
from scrapy import Spider
from scrapy.crawler import CrawlerProcess

# %%
import logging
import os

# %% [markdown]
# !dir   --> dodanie wykrzyknika powoduje wykonanie polecenia powłoki

# %% [markdown]
# ##### Funkcja próbująca usunąć plik jeśli już istnieje w celu uniknięcia błędów i dopisywania danych

# %%
def try_remove (filename):
    try:
        os.remove(filename)
    except OSError:
        pass

# %% [markdown]
# #### Właściwa klasa scrapująca:

# %%
class BookingComOPinions(Spider):
    name = 'BookingComOpinionsSpider' #nazwa obowiazkowa
    
    custom_settings = {
        'FEED_URI': '%(json_file)s',
        'FEED_FORMAT': 'json', #sposob formatowania rezultatow
        'DOWNLOAD_DELAY': 3, #czas, zbyt maly moze nas zbanowac
        'LOG_LEVEL': logging.DEBUG,
        'EXTENSIONS': {
            'scrapy.extensions.closespider.CloseSpider':1 #klasa pozwala wykorzystac specjalny rodzaj wyjatku ktory powinien 
            #zatrzymac pająka; przydatne gdy dostaniemy bana i nie ma sensu dalej scrapowac
        },
        'CLOSESPIDER_ITEMCOUNT': 10 #system zacznie sie zatrzymywac po pobraniu 10 hotelow
    }
    
    def parse (self, response):
        hotels = response.css('div.sr_item')
        for hotel in hotels:
            hotel_name = hotel.css('span.sr-hotel__name::text').get().strip() #strip obcina biale znaki z tekstu
            hotel_link = hotel.css('.hotel_name_link.url').pop()
            yield response.follow(hotel_link, self.parse_hotel,
                                 meta={'hotel': hotel_name})
        
 #       for link in response.css('a[data-page-next]'): #pop() nie moze tu byc bo na ostatniej stronie brak elementu
 #           #zamiast tego petla ktora jest instrukcja warunkowa jesli element jest to wykonaj, a jak nie to nie wykonaj
 #           yield response.follow(link)
            
    def parse_hotel (self, response):
        hotel_name = response.meta['hotel']
        for reviews_link in response.css('a.show_all_reviews_btn'): #link do wszystkich recenzji
            yield response.follow(reviews_link, self.parse_reviews,
                                 meta={'hotel': hotel_name})
        
    def parse_reviews (self, response):
        hotel_name = response.meta['hotel']
        items = response.css('li.review_item')
        for item in items:
            publish_date = item.css('meta[itemprop="datePublished"]'
                                   '::attr(content)').get('')
            reviewer = item.css('div.review_item_reviewer')
            rev_count = reviewer.css('div.'
                                    'review_item_user_review_count::text').get('')
            ...
            
            review = item.css('div.review_item_review')
            rating = item.css('meta[itemprop="ratingValue"]'
                                   '::attr(content)').get('')
            raw_tags = review.css('li.review_info_tag::text').getall()
            tags= list(filter(None, map(str.strip, raw_tags)))
            ...
            
            
            yield{
                'hotel': hotel_name,
                'publish_date': publish_date,
                'rev_count': rev_count,
                'rating': rating,
                'tags': tags
            }
        
        for next_page in response.css('a#review_next_page_link'):
            yield response.follow(next_page, self.parse_reviews,
                                 meta=response.meta)

# %%
ENTRY_URL = 'https://www.booking.com/searchresults.pl.html?city=-273837'

# %%
json_file = 'Oslo.json' # przypisanie nowej nazwy do pliku
try_remove(json_file)   # usuwanie pliku jeśli istnieje

# %% [markdown]
# ##### Przygotowanie procesu przez crawlera, spider jest przygotowany i gotowy do pracy:

# %%
process = CrawlerProcess()
process.crawl(BookingComOPinions, start_urls = [ENTRY_URL],
             json_file = json_file)
# start_urls to lista tych adresów z których rozpoczynam przeszukiwanie
# Out:
# 2019-04-07 23:04:12 [scrapy.utils.log] INFO: Scrapy 1.5.2 started (bot: scrapybot)
# 2019-04-07 23:04:12 [scrapy.utils.log] INFO: Versions: lxml 4.2.5.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.5.1, w3lib 1.20.0, Twisted 18.9.0, Python 3.7.1 (default, Dec 10 2018, 22:54:23) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 18.0.0 (OpenSSL 1.1.1a  20 Nov 2018), cryptography 2.4.2, Platform Windows-10-10.0.17134-SP0
# 2019-04-07 23:04:12 [scrapy.crawler] INFO: Overridden settings: {'CLOSESPIDER_ITEMCOUNT': 10, 'DOWNLOAD_DELAY': 3, 'FEED_FORMAT': 'json', 'FEED_URI': '%(json_file)s', 'LOG_LEVEL': 10}
# 2019-04-07 23:04:12 [scrapy.extensions.telnet] INFO: Telnet Password: 5aed84efd66ae67f
# 2019-04-07 23:04:12 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.closespider.CloseSpider']
# 2019-04-07 23:04:12 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-04-07 23:04:12 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-04-07 23:04:12 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-04-07 23:04:12 [scrapy.core.engine] INFO: Spider opened
# 2019-04-07 23:04:12 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-07 23:04:12 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023

# %% [markdown]
# #### Uruchomienie procesu scrapowania:

# %%
process.start()
# Out:
# 2019-04-07 23:04:13 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?city=-501414> (referer: None)
# 2019-04-07 23:04:16 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/courtyard-gdynia-waterfront.pl.html> from <GET https://www.booking.com/hotel/pl/courtyard-gdynia-waterfront.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?city=-501414&dest_id=-501414&dest_type=city&offset=15> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:04:24 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/quadrille-conference-amp-spa.pl.html> from <GET https://www.booking.com/hotel/pl/quadrille-conference-amp-spa.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:28 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/dom-wczasowy-u-sowy.pl.html> from <GET https://www.booking.com/hotel/pl/dom-wczasowy-u-sowy.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:32 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/apartament-centrum-gdynia12.pl.html> from <GET https://www.booking.com/hotel/pl/apartament-centrum-gdynia12.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:36 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/blekitny-zagiel.pl.html> from <GET https://www.booking.com/hotel/pl/blekitny-zagiel.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:38 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/morski-gdynia.pl.html> from <GET https://www.booking.com/hotel/pl/morski-gdynia.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:41 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/apartament-swietojanska-gdynia1.pl.html> from <GET https://www.booking.com/hotel/pl/apartament-swietojanska-gdynia1.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:45 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/grand-tulipan.pl.html> from <GET https://www.booking.com/hotel/pl/grand-tulipan.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:50 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/rozany-gaj-gdynia.pl.html> from <GET https://www.booking.com/hotel/pl/rozany-gaj-gdynia.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:54 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/baltic-sun-gdynia.pl.html> from <GET https://www.booking.com/hotel/pl/baltic-sun-gdynia.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:04:58 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/gdynia_nadmorski.pl.html> from <GET https://www.booking.com/hotel/pl/gdynia_nadmorski.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:02 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/apartament-z-balkonem.pl.html> from <GET https://www.booking.com/hotel/pl/apartament-z-balkonem.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:05 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/apartament-no-1.pl.html> from <GET https://www.booking.com/hotel/pl/apartament-no-1.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:09 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/gdynia-centrum-gdynia1234.pl.html> from <GET https://www.booking.com/hotel/pl/gdynia-centrum-gdynia1234.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:12 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/apartment-zaglami.pl.html> from <GET https://www.booking.com/hotel/pl/apartment-zaglami.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:12 [scrapy.extensions.logstats] INFO: Crawled 2 pages (at 2 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-07 23:05:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/courtyard-gdynia-waterfront.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:19 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.booking.com/hotel/pl/dom-marynarza.pl.html> from <GET https://www.booking.com/hotel/pl/dom-marynarza.pl.html?from=searchresults%0A#hotelTmpl>
# 2019-04-07 23:05:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/quadrille-conference-amp-spa.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/dom-wczasowy-u-sowy.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/apartament-centrum-gdynia12.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/blekitny-zagiel.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/morski-gdynia.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/apartament-swietojanska-gdynia1.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/grand-tulipan.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/rozany-gaj-gdynia.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/baltic-sun-gdynia.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:05:52 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.booking.com/hotel/pl/baltic-sun-gdynia.pl.html#blockdisplay4> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2019-04-07 23:05:56 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/gdynia_nadmorski.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:06:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/apartament-z-balkonem.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:06:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/apartament-no-1.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:06:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/gdynia-centrum-gdynia1234.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:06:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/apartment-zaglami.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414)
# 2019-04-07 23:06:12 [scrapy.extensions.logstats] INFO: Crawled 17 pages (at 15 pages/min), scraped 0 items (at 0 items/min)
# 2019-04-07 23:06:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/searchresults.pl.html?city=-501414&dest_id=-501414&dest_type=city&offset=30> (referer: https://www.booking.com/searchresults.pl.html?city=-501414&dest_id=-501414&dest_type=city&offset=15)
# 2019-04-07 23:06:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/hotel/pl/dom-marynarza.pl.html> (referer: https://www.booking.com/searchresults.pl.html?city=-501414&dest_id=-501414&dest_type=city&offset=15)
# 2019-04-07 23:06:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html> (referer: https://www.booking.com/hotel/pl/courtyard-gdynia-waterfront.pl.html)
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-21', 'rev_count': '\n5 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-18', 'rev_count': '\n11 opinii\n', 'rating': '6.7', 'tags': ['W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-17', 'rev_count': '\n2 opinie\n', 'rating': '5', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-17', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-10', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-10', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-09', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-03-09', 'rev_count': '\n19 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-27', 'rev_count': '\n4 opinie\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-18', 'rev_count': '\n2 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.engine] INFO: Closing spider (closespider_itemcount)
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-18', 'rev_count': '\n17 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd służbowy', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-18', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-18', 'rev_count': '\n3 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-14', 'rev_count': '\n3 opinie\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-05', 'rev_count': '\n7 opinii\n', 'rating': '5', 'tags': ['Podróżujący ze znajomymi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-02-03', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-16', 'rev_count': '\n1 opinia\n', 'rating': '4.6', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-03', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-03', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-02', 'rev_count': '\n46 opinii\n', 'rating': '3.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-02', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2019-01-01', 'rev_count': '\n19 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-29', 'rev_count': '\n8 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-25', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-18', 'rev_count': '\n8 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-18', 'rev_count': '\n32 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-17', 'rev_count': '\n10 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-12-02', 'rev_count': '\n1 opinia\n', 'rating': '9', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-26', 'rev_count': '\n14 opinii\n', 'rating': '5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-26', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-23', 'rev_count': '\n23 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-22', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-22', 'rev_count': '\n1 opinia\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-20', 'rev_count': '\n5 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-19', 'rev_count': '\n7 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-19', 'rev_count': '\n1 opinia\n', 'rating': '4.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-17', 'rev_count': '\n59 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-11', 'rev_count': '\n10 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '4 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-11-10', 'rev_count': '\n11 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-27', 'rev_count': '\n10 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-22', 'rev_count': '\n10 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '3 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-22', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-18', 'rev_count': '\n46 opinii\n', 'rating': '9.2', 'tags': ['Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-16', 'rev_count': '\n1 opinia\n', 'rating': '8.8', 'tags': ['Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-15', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-15', 'rev_count': '\n2 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-10', 'rev_count': '\n3 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-01', 'rev_count': '\n1 opinia\n', 'rating': '6.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '3 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-10-01', 'rev_count': '\n3 opinie\n', 'rating': '5.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-23', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-22', 'rev_count': '\n80 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-18', 'rev_count': '\n12 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-14', 'rev_count': '\n2 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-12', 'rev_count': '\n16 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-10', 'rev_count': '\n3 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-08', 'rev_count': '\n6 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-09-03', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-26', 'rev_count': '\n4 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-24', 'rev_count': '\n11 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '3 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-24', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Business z widokiem na morze', '4 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-21', 'rev_count': '\n1 opinia\n', 'rating': '5', 'tags': ['Wyjazd służbowy', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-21', 'rev_count': '\n5 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '8 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-21', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '9 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-21', 'rev_count': '\n2 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-20', 'rev_count': '\n4 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '10 noclegów']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-20', 'rev_count': '\n3 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-20', 'rev_count': '\n2 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '6 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-20', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '3 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-20', 'rev_count': '\n8 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-19', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-19', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '2 noclegi']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-17', 'rev_count': '\n6 opinii\n', 'rating': '5.8', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój dwuosobowy typu Standard z 1 lub 2 łóżkami i widokiem na miasto', '4 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-17', 'rev_count': '\n2 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '5 noclegów']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-15', 'rev_count': '\n23 opinie\n', 'rating': '5.4', 'tags': ['Ze zwierzęciem', 'Wyjazd służbowy', 'W parze', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '1 nocleg']}
# 2019-04-07 23:06:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/courtyard-gdynia-waterfront.pl.html>
# {'hotel': 'Courtyard by Marriott Gdynia Waterfront', 'publish_date': '2018-08-15', 'rev_count': '\n6 opinii\n', 'rating': '5.4', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój dwuosobowy typu Premium z 1 lub 2 łóżkami i widokiem na morze', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html> (referer: https://www.booking.com/hotel/pl/quadrille-conference-amp-spa.pl.html)
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-04-07', 'rev_count': '\n16 opinii\n', 'rating': '6.3', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-04-02', 'rev_count': '\n1 opinia\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-03-31', 'rev_count': '\n33 opinie\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-03-30', 'rev_count': '\n50 opinii\n', 'rating': '5.8', 'tags': ['Grupa', '2 pokoje', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-03-23', 'rev_count': '\n10 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-03-18', 'rev_count': '\n17 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy typu Deluxe', '2 noclegi']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-03-11', 'rev_count': '\n1 opinia\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-28', 'rev_count': '\n11 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-25', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-20', 'rev_count': '\n39 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój Dwuosobowy', '1 nocleg']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-18', 'rev_count': '\n13 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-18', 'rev_count': '\n15 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-16', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-07', 'rev_count': '\n9 opinii\n', 'rating': '10', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy typu Deluxe', '1 nocleg']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-04', 'rev_count': '\n13 opinii\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '2 noclegi']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-02-03', 'rev_count': '\n32 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój Dwuosobowy typu Deluxe', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-01-27', 'rev_count': '\n3 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy typu Deluxe', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-01-25', 'rev_count': '\n26 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-01-18', 'rev_count': '\n8 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Apartament typu Suite z tarasem', '2 noclegi']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# {'hotel': 'Relais & Châteaux Hotel Quadrille', 'publish_date': '2019-01-16', 'rev_count': '\n13 opinii\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy typu Deluxe', '2 noclegi']}
# 2019-04-07 23:06:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/quadrille-conference-amp-spa.pl.html>
# ...
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-12-03', 'rev_count': '\n1 opinia\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-26', 'rev_count': '\n7 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-18', 'rev_count': '\n4 opinie\n', 'rating': '10', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-16', 'rev_count': '\n2 opinie\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój trzyosobowy', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-12', 'rev_count': '\n33 opinie\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój Dwuosobowy typu Deluxe', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-12', 'rev_count': '\n1 opinia\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-11-05', 'rev_count': '\n1 opinia\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój Dwuosobowy typu Deluxe', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-10-29', 'rev_count': '\n2 opinie\n', 'rating': '5.4', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-10-26', 'rev_count': '\n5 opinii\n', 'rating': '9.2', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój typu Deluxe z 2 łóżkami pojedynczymi', '4 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-10-01', 'rev_count': '\n8 opinii\n', 'rating': '7.1', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój typu Deluxe z 2 łóżkami pojedynczymi', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-29', 'rev_count': '\n9 opinii\n', 'rating': '8.8', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój trzyosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-25', 'rev_count': '\n5 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój z 2 łóżkami pojedynczymi', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-25', 'rev_count': '\n7 opinii\n', 'rating': '5.4', 'tags': ['Grupa', 'Pokój trzyosobowy', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-21', 'rev_count': '\n3 opinie\n', 'rating': '5.4', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-19', 'rev_count': '\n3 opinie\n', 'rating': '9.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój trzyosobowy', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-18', 'rev_count': '\n13 opinii\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój z 2 łóżkami pojedynczymi', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-15', 'rev_count': '\n2 opinie\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '3 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-12', 'rev_count': '\n3 opinie\n', 'rating': '9.6', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-03', 'rev_count': '\n7 opinii\n', 'rating': '4.2', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-03', 'rev_count': '\n9 opinii\n', 'rating': '8.3', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój z 2 łóżkami pojedynczymi', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-09-02', 'rev_count': '\n2 opinie\n', 'rating': '7.9', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-31', 'rev_count': '\n6 opinii\n', 'rating': '5.8', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-26', 'rev_count': '\n5 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-25', 'rev_count': '\n21 opinii\n', 'rating': '4.6', 'tags': ['Wyjazd służbowy', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-20', 'rev_count': '\n1 opinia\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-19', 'rev_count': '\n2 opinie\n', 'rating': '4.2', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-11', 'rev_count': '\n15 opinii\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-09', 'rev_count': '\n1 opinia\n', 'rating': '7.9', 'tags': ['Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '5 noclegów']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-08', 'rev_count': '\n8 opinii\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój Dwuosobowy', '3 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-06', 'rev_count': '\n4 opinie\n', 'rating': '8.8', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój czteroosobowy', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-05', 'rev_count': '\n3 opinie\n', 'rating': '7.5', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój czteroosobowy', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-04', 'rev_count': '\n11 opinii\n', 'rating': '6.3', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój Dwuosobowy typu Deluxe', '7 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-04', 'rev_count': '\n15 opinii\n', 'rating': '5.8', 'tags': ['Wyjazd służbowy', 'Grupa', 'Pokój jednoosobowy', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-04', 'rev_count': '\n1 opinia\n', 'rating': '2.9', 'tags': ['Wyjazd wakacyjny', 'Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '5 noclegów', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-08-02', 'rev_count': '\n1 opinia\n', 'rating': '6.3', 'tags': ['Rodzina z małymi dziećmi', 'Pokój trzyosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-31', 'rev_count': '\n1 opinia\n', 'rating': '6.7', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '2 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-30', 'rev_count': '\n6 opinii\n', 'rating': '5.4', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój typu Deluxe z 2 łóżkami pojedynczymi', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-29', 'rev_count': '\n27 opinii\n', 'rating': '5', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-24', 'rev_count': '\n1 opinia\n', 'rating': '5.4', 'tags': ['Wyjazd wakacyjny', 'Podróżujący w pojedynkę', 'Pokój jednoosobowy', '2 noclegi']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-23', 'rev_count': '\n16 opinii\n', 'rating': '5.4', 'tags': ['Podróżujący w pojedynkę', 'Pokój jednoosobowy', '1 nocleg']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-22', 'rev_count': '\n1 opinia\n', 'rating': '7.1', 'tags': ['Wyjazd wakacyjny', 'W parze', 'Pokój z 2 łóżkami pojedynczymi', '3 noclegi', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-16', 'rev_count': '\n2 opinie\n', 'rating': '3.3', 'tags': ['Wyjazd wakacyjny', 'Grupa', 'Pokój jednoosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.booking.com/reviews/pl/hotel/dom-marynarza.pl.html>
# {'hotel': 'Hotel Dom Marynarza', 'publish_date': '2018-07-15', 'rev_count': '\n15 opinii\n', 'rating': '6.9', 'tags': ['Wyjazd wakacyjny', 'Podróżujący ze znajomymi', 'Pokój trzyosobowy', '1 nocleg', 'Wysłana przez urządzenie mobilne']}
# 2019-04-07 23:07:23 [scrapy.extensions.feedexport] INFO: Stored json feed (782 items) in: gdynia.json
# 2019-04-07 23:07:23 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 29198,
#  'downloader/request_count': 52,
#  'downloader/request_method_count/GET': 52,
#  'downloader/response_bytes': 4890059,
#  'downloader/response_count': 52,
#  'downloader/response_status_count/200': 34,
#  'downloader/response_status_count/301': 18,
#  'dupefilter/filtered': 11,
#  'finish_reason': 'closespider_itemcount',
#  'finish_time': datetime.datetime(2019, 4, 7, 21, 7, 23, 842399),
#  'item_scraped_count': 782,
#  'log_count/DEBUG': 836,
#  'log_count/INFO': 12,
#  'request_depth_max': 4,
#  'response_received_count': 34,
#  'scheduler/dequeued': 52,
#  'scheduler/dequeued/memory': 52,
#  'scheduler/enqueued': 106,
#  'scheduler/enqueued/memory': 106,
#  'start_time': datetime.datetime(2019, 4, 7, 21, 4, 12, 959744)}
# 2019-04-07 23:07:23 [scrapy.core.engine] INFO: Spider closed (closespider_itemcount)

# %% [markdown]
# ##### get() , getall() redukuje selektory od stringu

# %% [markdown]
# ##### .pop(0)  zdejmuje pierwszy element z listy

# %% [markdown]
# # Po wyscrapowaniu danych ze strony można przystąpić do przygotowania ich do analizy:

# %%
logging.getLogger().setLevel(logging.INFO) 
# zmiana levelu wyświetlania info

# %%
import pandas as pd

# %%
df = pd.read_json(json_file) 
# df bo dataframe

# %% [markdown]
# ##### wyrzuamy napisy zawierające litery opiniae i spacje

# %%
df['rev_count'] = df['rev_count'].str.strip(' opinea') 
# df['rev_count'].str.strip() nie modyfikuje to dataframe, chyba że przypiszemy do tego samego obiektu

# %% [markdown]
# ##### Konwersja do intów:

# %%
#df['rev_count'] = df['rev_count'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0315b2c5d815> in <module>
# ----> 1 df['rev_count'] = df['rev_count'].astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     707         # work around NumPy brokenness, #1987
#     708         if np.issubdtype(dtype.type, np.integer):
# --> 709             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     710
#     711         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src\util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: '\n5 opinii\n'

# %% [markdown]
# ##### Prygotowanie danych do sprawdzenia jakie tagi wpływają na rating:

# %%
subset = df[['rating', 'tags']] 
subdf = [subset]

# %%
dum = subdf['tags'].map(lambda tags: '|'.join(tags)).str.get_dummies() 
# łączymy tagi dla danej opinii i dzielimy je separatorem  (w get_dummies() domyślny separator to |)

# %%
indicators = pd.concat([subdf['rating'], dum], axis = 1) 
# axis mówi wzdłóż której osi ma nastąpić złączenie

# %%
melted = pd.melt(indicators, id_vars=['rating'])
# id_vars zmienne które zostawiamy w spokoju

# %% [markdown]
# ##### Selekcjonowanie według kryterium:

# %%
positive = melted['value'] == 1
# wydobywamy wyrażenia z samymi 1 (a raczej odpowiedź na pytanie czy występuje w danym indeksie)
# taka lista może posłużyćza selektor danych w dataframe

# %%
selected = melted[positive]

# %%
aggregated = selected.groupby(['variable'])['rating'].agg(['mean','count'])
# groupby() wymaga podania listy tych kolumn wedłóg których ma nastąpić grupowanie
# fragment z rating to wycięcie interesującej kolumny
# agg() metoda agregacji przyjmująca jako parametr sposób agregowania, np. funkcja/słownik

# %% [markdown]
# ##### na koniec będzie sortowanie w celu zwizualizowanie jaki tag wpływa najbardziej na rating:

# %%
aggregated.sort_values(by = ['count']).tali(10) 
# sortowanie rosnąco według wartości count (10 ostatnich pozycji)

# %% [markdown]
# # KONIEC

# %% [markdown]
# class BookingOpinions(Spider):
#     name = 'BookingComOpinionsSpider' # nazwa jest obowiązkowa
#
#     custom_settings = {
#         'FEED_URI': '%(json_file)s',  # zapisanie rezultatów do pliku %()s wrzua do pola argument który jest stringiem s, wykrywa jedyny string pobrany jako argument
#         'FEED_FORMAT': 'json',        # wybór sposobu formatowania rezultatów
#         'DOWNLOAD_DELAY': 3,          # trzeba uważać żeby nie dać za małego czasu bo można zostać zbanowanym
#         'LOG_LEVEL': logging.DEBUG,   # poziom wartości informacji jakie będą wyświetlane (debug, warn error itp)
#         'EXTENSIONS': {
#             'scrapy.extensions.closespider.CloseSpider': 1 # klasa która pozwala wykorzystać specjalny rodzaj wyjątku który powinien zatrzymać pająka
#                                                            # CloseSpider przydaje się np. gdy dostaliśmy bana od strony więc nie ma sensu dalej szuka
#         },
#         'CLOSESPIDER_ITEMCOUNT': 10                                   # system zatrzyma się po porównaniu 10 hoteli
#     }
#
#     def parse(self, response):                                        # funkcja która będzie analizowała już wybraną stronę
#         hotels = response.css('div.sr_item')                          # lista bloków w których są opisane hotele
#         for hotel in hotels:
#             hotel_name = hotel.css('span.sr-hotel__name::text').get().strip() # hotel jest selektorem samym w sobie więc można na nim wykonać metodę .css()                          # obcinanie białych znaków z tekstu
#             hotel_link = hotel.css('.hotel_name_link.url').pop()              # . są do klas, [] do reszty ????
#             yield response.follow(hotel_link, self.parse_hotel,
#                                  meta={'hotel': hotel_name})                  # zakładamy historię meta-informacji która będzie działać w głąb
#
#         for link in response.css('a[data-page-next]'):
#         # pętla która jest instrukcją warunkową (jeśli jest element to wykona, jak nie ma to nie wykonuje)
#             yield response.follow(link)
#
#     def parse_hotel (self, response):
#         hotel_name = response.meta['hotel']                           # wykorzystanie wcześniej utworzonych meta danych do wydobycia nazwy
#         for reviews_link in response.css('a.show_all_reviews_btn'):   # parsowanie ścieżki do opinii o hotelu
#             yield response.follow(reviews_link, self.parse_reviews,   # przekazanie nazwy funkcji bez wywołania
#                                  meta = {'hotel': hotel_name})        # forwardowanie metadanych (same się nie dziedziczą)
#     def parse_reviews (self, response):
#         hotel_name = response.meta['hotel']
#         items = response.css('li.reviews_item')
#         for item in items:
#             publish_date = item.css('meta[itemprop= "datePublished"]'
#                                     '::attr(content)').get('')        # funkcja get nie wydobędzie niczego (zwraca None) chyba że w nawiasach od get wstawi się wartość domyślnątu '',  gdy nie ma szukanego selektora
#             reviewer = item.css('div.review_item_reviewer')
#             rev_count = review.css('div.review_item_user_review_count::text').get('')
#             ...
#             review = item.css('div.review_item_review')
#             rating = review.css('meta[itemprop="ratingValue"]::attr(content)').get('')
#
#             raw_tags = reviews.css('li.review_info_tag::text').getall()
#             tags = list(filter(None, map(str.strip, raw_tags)))
#             # pierwszym parametrem filter może być None (wyłapuje puste stringi), a drugi to lista ?? lub tekst?? filtrowana/y
#             ...
#             yield {
#                 'hotel': hotel_name,
#                 'publish_date': publish_date,
#                 'rev_count': rev_count,
#                 'rating': rating,
#                 'tags': tags
#             }
#
#         for next_page in response.css('a#review_next_page_link'):      # '#' bo szukamy po id
#             yield response.follow(next_page, self.parse_reviews,
#                                  meta=response.meta)
